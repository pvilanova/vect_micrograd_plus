# %% [markdown]
# ### Vectorized MicroGrad demo
#
# This notebook mirrors `demo.ipynb`, but uses the NumPy-backed vectorized engine. The key idea is that one `Value` can hold an entire array, so a dense layer is built from a small number of array operations like `X @ W + b` instead of thousands of scalar `Value` operations.

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from vect_micrograd.vect_engine import Value
from vect_micrograd.vect_nn import MLP

np.random.seed(31337)

# %% [markdown]
# #### Make a checkerboard dataset
#
# A checkerboard requires a more expressive network than the moon demo. This is exactly where scalar micrograd becomes slow, because every neuron decomposes into many tiny Python objects. The vectorized version keeps the same dynamic-autograd idea while letting NumPy do the dense array work.

# %%
def make_checkerboard(n=400, grid=4, noise=0.02, seed=42):
    rng = np.random.default_rng(seed)
    side = int(np.sqrt(n))
    xs = np.linspace(-1, 1, side)
    ys = np.linspace(-1, 1, side)
    xx, yy = np.meshgrid(xs, ys)
    X = np.c_[xx.ravel(), yy.ravel()]

    ix = ((X[:, 0] + 1) / (2 / grid)).astype(int).clip(0, grid - 1)
    iy = ((X[:, 1] + 1) / (2 / grid)).astype(int).clip(0, grid - 1)
    y = ((ix + iy) % 2) * 2 - 1

    X += rng.normal(size=X.shape) * noise
    return X.astype(float), y.astype(float).reshape(-1, 1)

X, y = make_checkerboard(n=4000, grid=8, noise=0.02)

plt.figure(figsize=(5, 5))
plt.scatter(X[:, 0], X[:, 1], c=y.ravel(), s=2, cmap='jet')
plt.title('Checkerboard dataset')
plt.show()

# %% [markdown]
# #### Initialize the vectorized model
#
# `model.parameters()` now returns a small list of array-valued `Value` objects: one weight matrix and one bias vector per layer. The number of scalar trainable parameters is still large enough for the checkerboard, but the number of Python autograd nodes is much smaller.

# %%
# Create a 4-layer network: 2 inputs → 16 hidden → ... → 16 hidden → 1 output
model = MLP(2, [128, 128, 128, 128, 1])

print(model)
print(f"number of scalar parameters: {sum(p.data.size for p in model.parameters()):,}")
print('number of Value parameter objects:', len(model.parameters()))
# Out:
# MLP of [Layer(2, 128), Layer(128, 128), Layer(128, 128), Layer(128, 128), Layer(128, 1)]
# number of scalar parameters: 50,049
# number of Value parameter objects: 10

# %% [markdown]
# #### Optimization loop

# %%
from vect_micrograd.optim import SGD, Adam, Lion
from vect_micrograd.utils import save_checkpoint, load_checkpoint, svm_loss, sample_batch

steps = 5000

# optimizer = SGD(model.parameters(), lr=1.0, total_steps=steps)
# optimizer = Adam(model.parameters(), lr=1e-2, total_steps=steps)
optimizer = Lion(model.parameters(), lr=1e-3, total_steps=steps, weight_decay=1e-2)

best_checkpoint = None
best_loss = float('inf')
best_step = -1
history = []

for k in range(steps):
    Xb, yb = sample_batch(X, y, batch_size=256)
    total_loss, acc = svm_loss(model, Xb, yb)

    loss_value = total_loss.item()
    history.append((k, loss_value, acc))

    if loss_value < best_loss:
        best_loss = loss_value
        best_step = k
        best_checkpoint = save_checkpoint(model)

    optimizer.zero_grad()
    total_loss.backward()
    optimizer.step(k)

    if k % 100 == 0:
        print(f'step {k:03d} loss {loss_value:.4f}, accuracy {acc*100:.1f}%')
# Out:
# step 000 loss 1.1087, accuracy 46.5%
# step 100 loss 0.9595, accuracy 60.2%
# step 200 loss 0.8611, accuracy 66.0%
# step 300 loss 0.7280, accuracy 73.0%
# step 400 loss 0.6915, accuracy 73.8%
# step 500 loss 0.6137, accuracy 75.0%
# step 600 loss 0.5690, accuracy 79.3%
# step 700 loss 0.4731, accuracy 85.2%
# step 800 loss 0.5637, accuracy 79.3%
# step 900 loss 0.4598, accuracy 84.8%
# step 1000 loss 0.4310, accuracy 85.9%
# step 1100 loss 0.4516, accuracy 83.6%
# step 1200 loss 0.4758, accuracy 82.8%
# step 1300 loss 0.4340, accuracy 85.9%
# step 1400 loss 0.4333, accuracy 85.9%
# step 1500 loss 0.3962, accuracy 86.3%
# step 1600 loss 0.3988, accuracy 85.9%
# step 1700 loss 0.3206, accuracy 89.1%
# step 1800 loss 0.3848, accuracy 86.3%
# step 1900 loss 0.2918, accuracy 91.8%
# step 2000 loss 0.3420, accuracy 88.7%
# step 2100 loss 0.3551, accuracy 90.2%
# step 2200 loss 0.3197, accuracy 89.1%
# step 2300 loss 0.3796, accuracy 87.5%
# step 2400 loss 0.3173, accuracy 90.6%
# step 2500 loss 0.3174, accuracy 90.2%
# step 2600 loss 0.3104, accuracy 91.4%
# step 2700 loss 0.3204, accuracy 90.2%
# step 2800 loss 0.2356, accuracy 93.8%
# step 2900 loss 0.3083, accuracy 91.0%
# step 3000 loss 0.2888, accuracy 93.0%
# step 3100 loss 0.2761, accuracy 91.4%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 17
#      13 history = []
#      14
#      15 for k in range(steps):
#      16     Xb, yb = sample_batch(X, y, batch_size=256)
# ---> 17     total_loss, acc = svm_loss(model, Xb, yb)
#      18
#      19     loss_value = total_loss.item()
#      20     history.append((k, loss_value, acc))
#
# File ~/Downloads/Karpathy/vect_micrograd/vect_micrograd/utils.py:76, in svm_loss(model, X, y, alpha)
#      60 def svm_loss(model, X, y, alpha=1e-4):
#      61     """L2-regularized SVM max-margin loss.
#      62
#      63     This function is deterministic: it computes the loss on exactly the
#    (...)     74         accuracy: float in [0, 1].
#      75     """
# ---> 76     scores = model(Value(X))
#      77     margins = (1 + scores * (-y)).relu()
#      78     data_loss = margins.mean()
#
# File ~/Downloads/Karpathy/vect_micrograd/vect_micrograd/vect_nn.py:46, in MLP.__call__(self, x)
#      44 x = x if isinstance(x, Value) else Value(x)
#      45 for layer in self.layers[:-1]:
# ---> 46     x = self.activation(layer(x))
#      47 return self.layers[-1](x)
#
# File ~/Downloads/Karpathy/vect_micrograd/vect_micrograd/vect_nn.py:27, in Layer.__call__(self, x)
#      25 def __call__(self, x):
#      26     x = x if isinstance(x, Value) else Value(x)
# ---> 27     out = x @ self.W
#      28     return out + self.b if self.b is not None else out
#
# File ~/Downloads/Karpathy/vect_micrograd/vect_micrograd/vect_engine.py:144, in Value.__matmul__(self, other)
#     142 def __matmul__(self, other):
#     143     other = other if isinstance(other, Value) else Value(other)
# --> 144     out = Value(self.data @ other.data, (self, other), "@")
#     146     def _backward():
#     147         # Common dense-layer case: (batch, in) @ (in, out).
#     148         if self.data.ndim == 2 and other.data.ndim == 2:
#
# File ~/Downloads/Karpathy/vect_micrograd/vect_micrograd/vect_engine.py:47, in Value.__init__(self, data, _children, _op)
#      43 """Stores a NumPy array and its gradient."""
#      45 __array_priority__ = 1000
# ---> 47 def __init__(self, data, _children=(), _op: str = ""):
#      48     self.data = _as_array(data)
#      49     self.grad = np.zeros_like(self.data, dtype=float)
#
# KeyboardInterrupt:

# %% [markdown]
# #### Restore the best checkpoint and evaluate on the full dataset

# %%
load_checkpoint(model, best_checkpoint)
full_loss, full_acc = svm_loss(model, X, y)

print(f'Restored checkpoint from step {best_step}, loss {best_loss:.4f}')
print(f'Full dataset: loss {full_loss.item():.4f}, accuracy {full_acc*100:.1f}%')
# Out:
# Restored checkpoint from step 4923, loss 0.2904
# Full dataset: loss 0.4122, accuracy 85.5%

# %% [markdown]
# #### Training curve

# %%
history = np.array(history)

plt.figure(figsize=(6, 4))
plt.plot(history[:, 0], history[:, 1], label='loss')
plt.plot(history[:, 0], history[:, 2], label='accuracy')
plt.xlabel('step')
plt.legend()
plt.title('Checkerboard test training')
plt.show()

# %% [markdown]
# #### Visualize the learned decision boundary

# %%
h = 0.02
x_min, x_max = X[:, 0].min() - 0.25, X[:, 0].max() + 0.25
y_min, y_max = X[:, 1].min() - 0.25, X[:, 1].max() + 0.25
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))
Xmesh = np.c_[xx.ravel(), yy.ravel()]

scores = model(Value(Xmesh))
Z = (scores.data > 0).reshape(xx.shape)

plt.figure(figsize=(6, 6))
plt.contourf(xx, yy, Z, cmap=plt.cm.Spectral, alpha=0.8)
plt.scatter(X[:, 0], X[:, 1], c=y.ravel(), s=4, cmap=plt.cm.Spectral)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.title('Checkerboard test')
plt.show()

# %%
from tests.test_value import (
    test_softmax_ce_probabilities_sum_to_one,
    test_softmax_ce_numerical_gradient,
    test_softmax_ce_loss_is_mean,
    test_softmax_ce_respects_upstream_grad,
)

test_softmax_ce_probabilities_sum_to_one()
test_softmax_ce_numerical_gradient()
test_softmax_ce_loss_is_mean()
test_softmax_ce_respects_upstream_grad()

print("All softmax_ce tests passed.")
# Out:
# All softmax_ce tests passed.
